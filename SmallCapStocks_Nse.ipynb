# %% [markdown]
# <a href="https://colab.research.google.com/github/sumeet022/SmallCapStocks/blob/main/SmallCapStocks_Nse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import os
import glob
import pandas as pd
import re
# !pip install datasets transformers

# %%
n = pd.read_csv(r"/content/NseLargeDeals")
n['date'] = pd.to_datetime(n['date'], format='%d-%b-%Y')
n['date'] = n['date'].apply(lambda x: x.strftime('%d-%m-%Y'))
n['date']=n['date'].apply(lambda x:x.replace('-','/'))

# %%
new_column_names = {
    'deal Date': 'date',
    'security NAME':'security_name',
    'buY/SELL': 'type',
    'quantity TRADED':'quantity',
    'trade PRICE/ WEIGHTED. AVG. PRICE':'price',
    'client NAME':'client_name'
    # Add more mappings as needed
}

# Use the rename() method to rename columns
n = n.rename(columns=new_column_names)
####
nse = n.iloc[:,[0,2,3,4,5,6]]
nse.info()
n['price'] = n['price'].apply(lambda x: re.sub(r'[^\d.]', '', x))
n['price'] = n['price'].astype(float)
# This part is to filter out unique elements where the people only brought and sold the shares not on the same day

filtered_df = n[~n.groupby(['date', 'client_name'])['type'].transform(lambda x: x.nunique() == 2)]
# Now, filter out rows for each client where they bought and sold on the same day
result_df = filtered_df.groupby('client_name').filter(lambda x: len(x) < 2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           512 non-null    object
#  1   security_name  512 non-null    object
#  2   client_name    512 non-null    object
#  3   type           512 non-null    object
#  4   quantity       512 non-null    object
#  5   price          512 non-null    object
# dtypes: object(6)
# memory usage: 24.1+ KB

# %%
LessThan10_GreaterThan5 = result_df[(result_df['price'] > 5) & (result_df['price'] < 10)]
LessThan5_GreaterThan4 = result_df[(result_df['price'] < 5) & (result_df['price'] > 4)]
LessThan4_GreaterThan3 = result_df[(result_df['price'] < 4) & (result_df['price'] > 3)]
LessThan3_GreaterThan2 = result_df[(result_df['price'] < 3) & (result_df['price'] > 2)]
LessThan2 = result_df[(result_df['price'] < 2)]
LessThan20_GreaterThan10 = result_df[(result_df['price'] > 10) & (result_df['price'] < 20)]
LessThan30_GreaterThan20 = result_df[(result_df['price'] > 20) & (result_df['price'] < 30)]
LessThan100_GreaterThan30 = result_df[(result_df['price'] > 30)]

# %%
LessThan5_GreaterThan4
# Out:
#            date     symbol              security_name  \
# 191  26/02/2024  KANANIIND      Kanani Industries Ltd
# 350  29/02/2024  GATECHDVR  GACM Technologies Limited
#
#                    client_name  type   quantity  price remarks
# 191  HARSHIL PREMJIBHAI KANANI  SELL  20,00,000   4.85       -
# 350  L7 HITECH PRIVATE LIMITED   BUY  21,04,110   4.96       -

# %%
LessThan4_GreaterThan3
# Out:
#            date    symbol           security_name  \
# 106  23/02/2024  SUNDARAM  Sundaram Multi Pap Ltd
# 111  23/02/2024  SUNDARAM  Sundaram Multi Pap Ltd
# 118  23/02/2024  SUNDARAM  Sundaram Multi Pap Ltd
# 119  23/02/2024  SUNDARAM  Sundaram Multi Pap Ltd
# 124  23/02/2024  SUNDARAM  Sundaram Multi Pap Ltd
# 235  26/02/2024  SUNDARAM  Sundaram Multi Pap Ltd
#
#                          client_name  type   quantity  price remarks
# 106           ANUP BIRMANAND AGRAWAL  SELL  23,94,960   3.82       -
# 111    DEEPIKA DAMJI PATEL CHAUDHARY  SELL  25,79,990   3.65       -
# 118            KANTA HARGOVIND BHURA  SELL  42,15,000   3.97       -
# 119            MADHUMATI ARVIND SHAH  SELL  25,80,000   3.90       -
# 124              PREMJI JIVRAJ SAVLA  SELL  25,80,000   3.57       -
# 235  TOPGAIN FINANCE PRIVATE LIMITED  SELL  31,50,000   3.43       -

# %%
LessThan3_GreaterThan2
# Out:
#            date   symbol              security_name        client_name  type  \
# 178  26/02/2024   CMMIPL  CMM Infraprojects Limited       SAMTA MUNDRA  SELL
# 461  01/03/2024   CMMIPL  CMM Infraprojects Limited  BHANDARI HITENDRA   BUY
# 509  01/03/2024  VIJIFIN       Viji Finance Limited      VIJAY KOTHARI   BUY
#
#      quantity  price remarks
# 178  2,01,000   2.65       -
# 461    99,000   2.45       -
# 509  4,36,492   2.96       -

# %%
LessThan2
# Out:
#            date      symbol             security_name           client_name  \
# 327  29/02/2024  ANTGRAPHIC   Antarctica Graphics Ltd         JYOTI KUTHARI
# 328  29/02/2024  ANTGRAPHIC   Antarctica Graphics Ltd  VISHNU KUMAR AGARWAL
# 352  29/02/2024       GODHA  Godha Cabcon Insulat Ltd      MADHU DEVI GODHA
#
#      type   quantity  price remarks
# 327  SELL  10,00,000   1.65       -
# 328   BUY  10,00,000   1.65       -
# 352  SELL  70,00,000   0.95       -

# %%
LessThan10_GreaterThan5
# Out:
#            date   symbol          security_name           client_name type  \
# 154  23/02/2024  TIJARIA  Tijaria Polypipes Ltd  STATSOL RESEARCH LLP  BUY
#
#      quantity  price remarks
# 154  1,99,436    9.1       -

# %%
LessThan20_GreaterThan10
# Out:
#            date      symbol          security_name  \
# 167  26/02/2024    ATALREAL  Atal Realtech Limited
# 168  26/02/2024    ATALREAL  Atal Realtech Limited
# 169  26/02/2024    ATALREAL  Atal Realtech Limited
# 177  26/02/2024      BRIGHT   Bright Solar Limited
# 424  29/02/2024     TIJARIA  Tijaria Polypipes Ltd
# 463  01/03/2024  GANGAFORGE  Ganga Forging Limited
#
#                             client_name  type   quantity  price remarks
# 167              BHAVESH KIRTI MATHURIA  SELL   7,46,956  15.56       -
# 168              KAUSHIK MAHESH WAGHELA   BUY   9,06,990  15.72       -
# 169                SAURABH P GANDHI HUF  SELL   4,53,047  16.02       -
# 177  XTENDED BUSINESS REPORTING LIMITED  SELL   1,62,000  10.85       -
# 424    THUNDERSTRIKE QUANT RESEARCH LLP   BUY   1,90,000  11.00       -
# 463               SMITAL SURESH THAKKAR   BUY  11,00,000  12.15       -

# %%
LessThan30_GreaterThan20
# Out:
#            date     symbol            security_name  \
# 73   23/02/2024      MOKSH  Moksh Ornaments Limited
# 206  26/02/2024  MANUGRAPH     Manugraph India Ltd.
# 448  01/03/2024  ASHOKAMET   Ashoka Metcast Limited
# 449  01/03/2024  ASHOKAMET   Ashoka Metcast Limited
#
#                       client_name  type  quantity  price remarks
# 73      SHABBIR NAZMUDDIN PARATHA  SELL  3,72,930  22.50       -
# 206         BHARAT KUNVERJI KENIA   BUY  1,98,000  25.38       -
# 448  AKHIL RETAIL PRIVATE LIMITED  SELL  2,50,000  25.10       -
# 449                    AKHIL SHAH  SELL  2,55,536  24.93       -

# %%
LessThan100_GreaterThan30
# Out:
#            date     symbol              security_name  \
# 0    23/02/2024     AHLADA   Ahlada Engineers Limited
# 1    23/02/2024     AMIORG       Ami Organics Limited
# 3    23/02/2024   ATMASTCO           Atmastco Limited
# 4    23/02/2024   ATMASTCO           Atmastco Limited
# 5    23/02/2024   ATMASTCO           Atmastco Limited
# ..          ...        ...                        ...
# 502  01/03/2024     SADHAV    Sadhav Shipping Limited
# 503  01/03/2024  SKIPPERPP            Skipper Limited
# 504  01/03/2024  SONUINFRA     Sonu Infratech Limited
# 505  01/03/2024  SUVENPHAR  Suven Pharmaceuticals Ltd
# 506  01/03/2024  SUVENPHAR  Suven Pharmaceuticals Ltd
#
#                                            client_name  type   quantity  \
# 0                                 K I VARAPRASAD REDDY  SELL     68,407
# 1                      SAGEONE INVESTMENT ADVISORS LLP   BUY   2,50,000
# 3    ASNANI STOCK BROKER PRIVATE LIMITED - ERROR AC...  SELL   3,08,800
# 4                               HEMANT KADVABHAI BHOOT   BUY   1,82,400
# 5                                          ROHAN GUPTA   BUY   2,86,400
# ..                                                 ...   ...        ...
# 502     YUGA STOCKS AND COMMODITIES PRIVATE LIMITED  .   BUY   1,10,400
# 503                        INTER GLOBE FINANCE LIMITED   BUY     74,876
# 504   NAV CAPITAL VCC - NAV CAPITAL EMERGING STAR FUND  SELL     54,000
# 505              ABU DHABI INVESTMENT AUTHORITY STABLE   BUY  15,74,000
# 506                    AMANSA HOLDINGS PRIVATE LIMITED  SELL  31,26,653
#
#        price remarks
# 0     124.64       -
# 1    1075.00       -
# 3      95.55       -
# 4      91.48       -
# 5      91.25       -
# ..       ...     ...
# 502   135.73       -
# 503   186.57       -
# 504    54.71       -
# 505   698.15       -
# 506   689.19       -
#
# [76 rows x 8 columns]
